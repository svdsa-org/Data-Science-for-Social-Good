# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
def get_sjodp(url):
    
    # Author: Julius Cheng
    
    js  = json.loads(requests.get(url).text)

    cols = []
    for item in js['result']['fArray']:
        if not item.get('fHeader'):
            break
        cols.append(item['fStr'])

    data = [[] for col in cols]
    for i, item in enumerate(js['result']['fArray']):
        if item.get('fHeader'):
            continue
        elif item.get('fStr'):
            data[i % len(cols)].append(item['fStr'])
        elif item.get('fNum'):
            data[i % len(cols)].append(item['fNum'])
        else:
            data[i % len(cols)].append('NaN')

    data_dict = dict(x for x in zip(cols, data))
    return data_dict

# %%
url = 'http://api.data.sanjoseca.gov/api/v2/datastreams/911-CALL-DATA/data.json/?auth_key=db647c82ee835f3e289d09ab471cea48d30e156b&limit=50000'

# %%
data = get_sjodp(url)
df = pd.DataFrame.from_dict(data)

# %%
df.describe(include='all')
# Out:
#        ADDRESS CALLTYPE_CODE CALL_NUMBER    CALL_TYPE              CDTS  \
# count      999           999         999          999               999
# unique     778           104         979          104               992
# top        NaN           415  P181231035  DISTURBANCE  20180503050121PD
# freq        28            94           3           94                 2
# mean       NaN           NaN         NaN          NaN               NaN
# std        NaN           NaN         NaN          NaN               NaN
# min        NaN           NaN         NaN          NaN               NaN
# 25%        NaN           NaN         NaN          NaN               NaN
# 50%        NaN           NaN         NaN          NaN               NaN
# 75%        NaN           NaN         NaN          NaN               NaN
# max        NaN           NaN         NaN          NaN               NaN
#
#             CITY COMMON_PLACE_NAME      EID  \
# count        999               999      999
# unique         1               160      977
# top     San Jose               NaN  7160962
# freq         999               783        4
# mean         NaN               NaN      NaN
# std          NaN               NaN      NaN
# min          NaN               NaN      NaN
# 25%          NaN               NaN      NaN
# 50%          NaN               NaN      NaN
# 75%          NaN               NaN      NaN
# max          NaN               NaN      NaN
#
#                                      FINAL_DISPO FINAL_DISPO_CODE  \
# count                                        999              999
# unique                                        16               18
# top     No report required; dispatch record only                N
# freq                                         412              412
# mean                                         NaN              NaN
# std                                          NaN              NaN
# min                                          NaN              NaN
# 25%                                          NaN              NaN
# 50%                                          NaN              NaN
# 75%                                          NaN              NaN
# max                                          NaN              NaN
#
#         OFFENSE_DATE OFFENSE_TIME PRIORITY   REPORT_DATE STATE
# count   9.990000e+02          999      999  9.990000e+02   999
# unique           NaN          975        6           NaN     1
# top              NaN  PT22H52M30S        3           NaN    CA
# freq             NaN            3      334           NaN   999
# mean    1.525297e+12          NaN      NaN  1.525297e+12   NaN
# std     2.571231e+07          NaN      NaN  2.571231e+07   NaN
# min     1.525219e+12          NaN      NaN  1.525219e+12   NaN
# 25%     1.525306e+12          NaN      NaN  1.525306e+12   NaN
# 50%     1.525306e+12          NaN      NaN  1.525306e+12   NaN
# 75%     1.525306e+12          NaN      NaN  1.525306e+12   NaN
# max     1.525306e+12          NaN      NaN  1.525306e+12   NaN

# %%
fig = plt.figure(figsize=(21,8))
plt.title('Call Type Histogram of 50,000 SJPD Calls')
df['CALL_TYPE'].value_counts()[0:75].plot(kind='bar')
plt.savefig('police_hist.png')
plt.show()
