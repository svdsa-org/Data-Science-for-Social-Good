# %%
library(gdata)

# %%
scc_primary <- read.xls('scc_election.xlsx', perl = "C:\\Perl64\\bin\\perl.exe")

# %%
scc_primary
# Out:
#    Table.of.Contents
# 1  Page
# 2  1
# 3  2
# 4  3
# 5  4
# 6  5
# 7  6
# 8  7
# 9  8
# 10 9
# 11 10
# 12 11
# 13 12
# 14 13
# 15 14
# 16 15
# 17 16
# 18 17
# 19 18
# 20 19
# 21 20
# 22 21
# 23 22
# 24 23
# 25 24
# 26 25
# 27 26
# 28 27
# 29 28
# 30 29
# 31 30
# 32 31
# 33 32
# 34 33
# 35 34
# 36 35
# 37 36
# 38 37
# 39 38
# 40 39
# 41 40
# 42 41
# 43 42
# 44 43
# 45 44
# 46 45
# 47 46
# 48 47
# 49 48
# 50 49
# 51 50
#    X
# 1  Contest
# 2  Registered Voters
# 3  GOVERNOR (Vote For 1)
# 4  Lieutenant Governor (Vote For 1)
# 5  Secretary of State (Vote For 1)
# 6  State Controller (Vote For 1)
# 7  State Treasurer (Vote For 1)
# 8  Attorney General (Vote For 1)
# 9  Insurance Commissioner (Vote For 1)
# 10 Board of Equalization, District 2 (Vote For 1)
# 11 UNITED STATES SENATOR (Vote For 1)
# 12 US Representative, District 17 (Vote For 1)
# 13 US Representative, District 18 (Vote For 1)
# 14 US Representative, District 19 (Vote For 1)
# ...
