# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D 
import numpy as np

# %%
mpl.text.Text?

# %%
xlsx = pd.ExcelFile('scc_election.xlsx')
table_of_contents = pd.read_excel(xlsx, 0, skiprows=3)

scc_primary = {}
for i, name in enumerate(table_of_contents['Contest']):
    if i == 0:
        scc_primary['{}'.format(str(name))] = pd.read_excel(xlsx, i+1)
    else:
        scc_primary['{}'.format(str(name))] = pd.read_excel(xlsx, i+1, header=[0,1])

mean_find = scc_primary['Registered Voters']
mean_find.drop(scc_primary['Registered Voters'].tail(1).index,inplace=True)
print np.average(mean_find['Registered Voters'])
# Out:
# 856.506072874

# %%
reg_vote_min = 300

df = scc_primary['Registered Voters'][scc_primary['Registered Voters']['Registered Voters']>reg_vote_min]
df = df.dropna()
df.drop(df.tail(1).index,inplace=True)
df.set_index('County')

df['Voter Turnout'] = [float(str(i).strip('%')) for i in df['Voter Turnout']]
df.sort_values('Voter Turnout')

print "There are {} precincts with over {} registered voters.".format(len(df), reg_vote_min)
df.head()
# Out:
# There are 828 precincts with over 300 registered voters.
#      County  Registered Voters  Ballots Cast  Voter Turnout
# 0  PCT 1001               1338           407          30.42
# 1  PCT 1003               1132           357          31.54
# 2  PCT 1006               1130           347          30.71
# 3  PCT 1008                717           230          32.08
# 4  PCT 1009               1000           286          28.60

# %%
scc_primary.keys()
# Out:
# ['STATE ASSEMBLY, District 27 (Vote For 1)',
#  'Measure G - East Side UHSD Parcel Tax (Vote For 1)',
#  'STATE SENATOR, District 10 (Vote For 1)',
#  'SAN JOSE City Council, Dist 7 (Vote For 1)',
#  'Sup of Public Instruction (Vote For 1)',
#  'SHERIFF (Vote For 1)',
#  'ASSESSOR (Vote For 1)',
#  'RECALL, Superior Court Judge, Successor (Vote For 1)',
#  'GOVERNOR (Vote For 1)',
#  'State Controller (Vote For 1)',
#  'Proposition 72 - Property-Tax Reassessments (Vote For 1)',
#  'SAN JOSE City Council, Dist 3 (Vote For 1)',
#  'US Representative, District 18 (Vote For 1)',
#  'US Representative, District 19 (Vote For 1)',
#  'US Representative, District 17 (Vote For 1)',
#  'Measure H - Cambrian SD Parcel Tax (Vote For 1)',
#  'Measure E - Mt. View - Los Altos UHSD Bonds (Vote For 1)',
#  'STATE ASSEMBLY, District 29 (Vote For 1)',
#  'Bay Area Toll Authority - Regional Measure 3 (Vote For 1)',
#  'Attorney General (Vote For 1)',
#  'SAN JOSE City Council, Dist 1 (Vote For 1)',
# ...

# %%
df_gov = df.join(scc_primary['GOVERNOR (Vote For 1)'],
                          on='County', how='left')
df_gov['Percent Cox'] = df_gov['REP - JOHN H. COX', 'Total Votes'] / df_gov['Ballots Cast']
df_gov = df_gov.sort_values('Voter Turnout')

df_norm = df_gov['Percent Cox'] / max(df_gov['Percent Cox'])
color = cm.coolwarm(df_norm)

# %%
scc_primary['Measure A - City of Santa Clara Charter Amendment (Vote For 1)'].keys()
# Out:
# MultiIndex(levels=[[u'NO', u'Unnamed: 0_level_0', u'YES'], [99, u'Election', u'Registered Voters', u'Total', u'Total Votes']],
#            labels=[[1, 0, 0, 2, 2, 2], [2, 0, 4, 1, 4, 3]],
#            names=[None, u'County'])

# %%
df_gov = df.join(scc_primary['Measure A - City of Santa Clara Charter Amendment (Vote For 1)'],
                          on='County', how='left')
df_gov = df_gov.dropna()
df_gov['Percent Cox'] = df_gov['YES', 'Total Votes'] / df_gov['YES', 'Total']
df_gov = df_gov.sort_values('Voter Turnout')

cox_norm = df_gov['Percent Cox'] / max(df_gov['Percent Cox'])
cmap = 'RdBu'
color = cm.RdBu(df_gov['Percent Cox'])

# %%
int(max(df_gov['Voter Turnout'])/5.)
# Out:
# 5

# %%
xticks = np.linspace(0, int(max(df_gov['Voter Turnout'])), int(max(df_gov['Voter Turnout'])/5.))
xticks
# Out:
# array([  0.,   7.,  14.,  21.,  28.])

# %%
alpha = .7

fig = plt.figure(figsize=(16,5+len(df_gov)/4))
ax = fig.add_subplot(111)

df_gov['Voter Turnout'].plot(kind='barh', ax=ax, alpha=.7,
                             legend=False, color=color,
                             edgecolor='w', xlim=(0,max(df_gov['Voter Turnout'])),
                             title='SCC Measure A Voter Data by Precinct')
ax.grid(False)
ax.set_frame_on(False)

ax.set_title(ax.get_title(), fontsize=36, alpha=alpha, ha='left', y=1.8)
plt.subplots_adjust(top=0.9)
ax.title.set_position((0, 1.10))

ax.xaxis.set_label_position('top')
ax.set_xlabel('Voter Turnout Percentage', fontsize=20, alpha=alpha, ha='left')
ax.set_ylabel('Precinct', fontsize=20, alpha=alpha)
ax.xaxis.set_label_coords(0, 1.06)
ax.xaxis.tick_top()
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')
 
xticks = np.linspace(0, int(max(df_gov['Voter Turnout'])), int(max(df_gov['Voter Turnout'])/5.))
ax.xaxis.set_ticks(xticks)
ax.set_xticklabels(['{:.0f}%'.format(val) for val in xticks], fontsize=16, alpha=alpha)

yticks = [item.get_text() for item in ax.get_yticklabels()]
ax.set_yticklabels(yticks, fontsize=16, alpha=alpha)
ax.yaxis.set_tick_params(pad=12)  


hmin, hmax = 0.3, 0.9
xmin, xmax = min(df_gov['Registered Voters']), max(df_gov['Registered Voters'])

f = lambda x: hmin + (hmax-hmin)*(x-xmin)/(xmax-xmin)
heights = [f(x) for x in df_gov['Registered Voters']]

for container in ax.containers:
    for i, child in enumerate(container.get_children()):
        child.set_y(child.get_y()- 0.125 + 0.5-heights[i]/2)
        plt.setp(child, height=heights[i])

ax2 = fig.add_subplot(236)
# plt.subplots_adjust(left=.5, right=1.5)
ax2.grid(False)
ax2.set_frame_on(False)
ax2.set_yticklabels([])
ax2.set_xticklabels([])
ax2.yaxis.set_ticks_position('none')
ax2.xaxis.set_ticks_position('none')

l1 = Line2D([], [], linewidth=6, color='k', alpha=alpha) 
l2 = Line2D([], [], linewidth=12, color='k', alpha=alpha) 
l3 = Line2D([], [], linewidth=22, color='k', alpha=alpha)

labels = [str(min(df_gov['Registered Voters'])), 
          str(int(np.mean(df_gov['Registered Voters']))),
          str(max(df_gov['Registered Voters']))]
 
# Position legend in lower right part
# Set ncol=3 for horizontally expanding legend
leg = ax2.legend([l1, l2, l3], labels, ncol=3, frameon=False, fontsize=12, 
                 bbox_to_anchor=[1.18, 0.15], handlelength=1, 
                 handletextpad=2, columnspacing=2,
                 title='Number of Registered Voters per Precinct')
 
# Customize legend title
# Set position to increase space between legend and labels
plt.setp(leg.get_title(), fontsize=16, alpha=alpha)
leg.get_title().set_position((0, 10))

sm = plt.cm.ScalarMappable(cmap=cmap,
                           norm=mpl.colors.Normalize(vmin=0,
                                                     vmax=1))
sm._A = []

cbar = plt.colorbar(sm, ax=ax2, orientation='horizontal',
                    alpha=.25, aspect=16, pad=.25)
cbar.solids.set_edgecolor("face")
cbar.outline.set_visible(False)
cbar.ax.tick_params(labelsize=12)

mytks = np.arange(0,1.1,.25)
cbar.set_ticks(mytks)
cbar.ax.set_xticklabels(['{:.0f}%'.format(a*100) for a in mytks], alpha=alpha)
cbar.ax.set_title('Percent Votes for Measure A per Precinct', alpha=alpha, 
                  fontsize=16)
cbarxtks = plt.getp(cbar.ax.axes, 'xticklines')
plt.setp(cbarxtks, visible=False)
plt.savefig('test.png', bbox_inches='tight', dpi=300)
plt.show()
